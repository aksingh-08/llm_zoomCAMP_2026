# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
custom_instructions = '''
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
'''.strip()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions = custom_instructions,
)

# %%
answer = assistant.rag('I just discovered the course, can I still join?')
print(answer)
# Out:
# Yes, you can still join the course, but if you want to receive a certificate, you need to submit your project while submissions are still being accepted.

# %%
print(assistant.rag("How do I get a certificate?"))
# Out:
# To get a certificate, you need to follow these guidelines:
#
# 1. **Finish the course with a "live" cohort**: You cannot get a certificate if you take the course in self-paced mode.
# 2. **Peer-review 3 capstone projects**: After submitting your own project, you need to peer-review 3 capstone projects, which can only be done during the time the course is running.
# 3. **Pass the Capstone project**: While homework is not mandatory, passing the Capstone project is necessary to get a certificate.
#
# Additionally, to ensure your certificate is issued with the correct name, make sure to:
#
# * Update your official name in the "Edit Course Profile" section, as this will be the name that appears on your certificate.
# * Use the "Edit Course Profile" section to change your display name if you want to be known by a different nickname.
#
# By following these guidelines, you can obtain a certificate for completing the course.

# %%
print(assistant.rag("Can I still join the course after it started?"))
# Out:
# According to the provided context, the answer to your question is: **Yes, you can still join the course after it started**. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted. Additionally, you will need to have joined the course as part of a "live" cohort, as certificates are not awarded for self-paced mode.

# %%
print(assistant.rag("How do I run Ollama locally?"))
# Out:
# To run Ollama locally, follow these steps:
#
# 1. **Install Ollama**: Visit [https://ollama.com/download](https://ollama.com/download) and download the installer for your operating system:
#    - **macOS**: Download the `.pkg` file and install it.
#    - **Windows**: Download the `.msi` file and install it.
#    - **Linux**: Run the command `curl -fsSL https://ollama.com/install.sh | sh` in your terminal.
#
# 2. **Run Ollama**: Open a terminal and type `ollama run llama3`. This will:
#    - Download the LLaMA 3 model (~4GB).
#    - Start the model locally.
#    - Open a chat-like interface where you can type questions.
#
# 3. **Test the Ollama local server**: Run the command `curl http://localhost:11434` to test the server. You should receive a response similar to `{"models": [...]}`.
#
# 4. **Install the Python client (optional)**: If you want to use the Python client, install it with `pip install ollama`. You can then use the Python example provided to interact with Ollama.
#
# If you encounter any issues, such as a connection refused error, you can try restarting the Ollama server using the command `!nohup ollama serve > nohup.out 2>&1 &`.
