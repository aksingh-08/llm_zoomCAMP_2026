# %%
from opentelemetry import trace
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import ConsoleSpanExporter, SimpleSpanProcessor

provider = TracerProvider()
provider.add_span_processor(
    SimpleSpanProcessor(ConsoleSpanExporter())
)
trace.set_tracer_provider(provider)

tracer = trace.get_tracer("llm-zoomcamp")

# %%
# Question 1

# %%
from starter import rag

query = "How does the agentic loop keep calling the model until it stops?"
answer = rag.rag(query)
print(answer)
# Out:
# {
#     "name": "search",
#     "context": {
#         "trace_id": "0xed0f70c7b8bbfcdbb48a81d953a2040c",
#         "span_id": "0xeb318c68af4ec27f",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xdad75cc791469fc3",
#     "start_time": "2026-07-18T06:53:24.647278Z",
#     "end_time": "2026-07-18T06:53:24.652752Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "llm",
#     "context": {
#         "trace_id": "0xed0f70c7b8bbfcdbb48a81d953a2040c",
#         "span_id": "0x95a5d9d85e38079f",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xdad75cc791469fc3",
#     "start_time": "2026-07-18T06:53:24.654054Z",
#     "end_time": "2026-07-18T06:53:43.445112Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "rag",
#     "context": {
#         "trace_id": "0xed0f70c7b8bbfcdbb48a81d953a2040c",
#         "span_id": "0xdad75cc791469fc3",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-07-18T06:53:24.647208Z",
#     "end_time": "2026-07-18T06:53:43.446712Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# By wrapping the conversation in a while-True loop that drives function calling. Each iteration:
#
# - Send the developer instructions plus the full message history (memory) to the model.
# - If the model returns a tool/function call (e.g., search), execute the tool, append its result to the history, and loop to call the model again.
# - If the model returns a normal answer (no tool call), break the loop and return the answer.
#
# ToyAIKit’s runner implements exactly this “send messages → run any function calls → repeat until the model is done” pattern.

# %%
with tracer.start_as_current_span("my_operation") as span:
    # your code here
    span.set_attribute("my_key", "my_value")
# Out:
# {
#     "name": "my_operation",
#     "context": {
#         "trace_id": "0x1d516290375308b89959852029858b78",
#         "span_id": "0x06b71bf968a9014a",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-07-18T06:53:43.456711Z",
#     "end_time": "2026-07-18T06:53:43.456749Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "my_key": "my_value"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }

# %%
# Question 2

# %%
import importlib
import starter

importlib.reload(starter)
from starter import rag
query = "How does the agentic loop keep calling the model until it stops?"
answer = rag.rag(query)
# Out:
# {
#     "name": "search",
#     "context": {
#         "trace_id": "0x9f7f55ebd177f41c3a3fc99baaf07d26",
#         "span_id": "0xa3ce7369e0d09999",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe111e4d7044783ca",
#     "start_time": "2026-07-18T07:14:19.840135Z",
#     "end_time": "2026-07-18T07:14:19.843956Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "llm",
#     "context": {
#         "trace_id": "0x9f7f55ebd177f41c3a3fc99baaf07d26",
#         "span_id": "0x3163db9cb9d6736d",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe111e4d7044783ca",
#     "start_time": "2026-07-18T07:14:19.847664Z",
#     "end_time": "2026-07-18T07:14:47.497235Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "model": "openai/gpt-5",
#         "input_tokens": 2617,
#         "output_tokens": 990,
#         "total_tokens": 3607,
#         "cost": 0.00641775
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "rag",
#     "context": {
#         "trace_id": "0x9f7f55ebd177f41c3a3fc99baaf07d26",
#         "span_id": "0xe111e4d7044783ca",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-07-18T07:14:19.840055Z",
#     "end_time": "2026-07-18T07:14:47.499660Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }

# %%
import importlib
import rag_helper
import rag_traced
import starter
importlib.reload(rag_helper)
importlib.reload(rag_traced)
importlib.reload(starter)
# Out:
# <module 'starter' from 'C:\\Users\\ashis\\Desktop\\llm_zoomCAMP_2026\\05-monitoring\\05-homework\\starter.py'>

# %%
# Question 3

# %%
from starter import rag
query = "How does the agentic loop keep calling the model until it stops?"
answer = rag.rag(query)
# Out:
# Search took 4.53 ms
# {
#     "name": "search",
#     "context": {
#         "trace_id": "0x6dc033ca89aeaa4f597915fe635f8847",
#         "span_id": "0xb94b20db4cd0f2b2",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3e0b1cfbada51657",
#     "start_time": "2026-07-18T07:30:12.566973Z",
#     "end_time": "2026-07-18T07:30:12.572461Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# LLM took 12.931 seconds
# {
#     "name": "llm",
#     "context": {
#         "trace_id": "0x6dc033ca89aeaa4f597915fe635f8847",
#         "span_id": "0x9c3a1de7f18ea932",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3e0b1cfbada51657",
#     "start_time": "2026-07-18T07:30:12.576438Z",
#     "end_time": "2026-07-18T07:30:25.508101Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "duration_seconds": 12.930720899996231,
#         "model": "openai/gpt-5",
#         "input_tokens": 2617,
#         "output_tokens": 783,
#         "total_tokens": 3400,
#         "cost": 0.00548625
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "rag",
#     "context": {
#         "trace_id": "0x6dc033ca89aeaa4f597915fe635f8847",
#         "span_id": "0x3e0b1cfbada51657",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-07-18T07:30:12.566888Z",
#     "end_time": "2026-07-18T07:30:25.510915Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.44.0",
#             "service.instance.id": "e05d13c4-80f6-4bf9-a0db-8d814815527a",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }

# %%
# Question 4

# %%
import importlib
import exporter
importlib.reload(exporter)
# Out:
# <module 'exporter' from 'C:\\Users\\ashis\\Desktop\\llm_zoomCAMP_2026\\05-monitoring\\05-homework\\exporter.py'>

# %%
from exporter import SQLiteSpanExporter

from opentelemetry import trace
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import ConsoleSpanExporter, SimpleSpanProcessor

provider = TracerProvider()
provider.add_span_processor(
    SimpleSpanProcessor(SQLiteSpanExporter("traces.db"))
)
trace.set_tracer_provider(provider)

tracer = trace.get_tracer("llm-zoomcamp")

# %%
from starter import rag
answer = rag.rag(
    "How does the agentic loop keep calling the model until it stops?"
)
# Out:
# Search took 4.86 ms
# LLM took 11.041 seconds

# %%
# Question 5

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("traces.db")

df = pd.read_sql_query("""
SELECT
    name,
    SUM(end_time - start_time) AS total_duration_ns
FROM spans
WHERE name != 'rag'
GROUP BY name
ORDER BY total_duration_ns DESC;
""", conn)

conn.close()

print(df)
# Out:
#      name  total_duration_ns
# 0     llm       140933638000
# 1  search          109460700

# %%
# Question 6

# %%
answer = rag.rag(
    "How does the agentic loop keep calling the model until it stops?"
)
# Out:
# Search took 6.80 ms
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 answer = rag.rag(
#       2     "How does the agentic loop keep calling the model until it stops?"
#       3 )
#
# File ~\Desktop\llm_zoomCAMP_2026\05-monitoring\05-homework\rag_traced.py:52, in RAGTraced.rag(self, query)
#      50 search_results = self.search(query)
#      51 prompt = self.build_prompt(query, search_results)
# ---> 52 response = self.llm(prompt)
#      53 return response.choices[0].message.content
#
# File ~\Desktop\llm_zoomCAMP_2026\05-monitoring\05-homework\rag_traced.py:23, in RAGTraced.llm(self, prompt)
#      17 start = time.perf_counter()
#      19 input_messages = [
#      20     {'role': 'developer', 'content': self.instructions},
#      21     {'role': 'user', 'content': prompt},
#      22 ]
# ---> 23 response = self.llm_client.beta.chat.completions.create(
#      24     model=self.model,
#      25     messages=input_messages,
#      26 )
#      27 duration = time.perf_counter() - start
#      28 print(f'LLM took {duration:.3f} seconds')
#
# File ~\desktop\llm_zoomcamp_2026\05-monitoring\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\desktop\llm_zoomcamp_2026\05-monitoring\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File ~\desktop\llm_zoomcamp_2026\05-monitoring\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\desktop\llm_zoomcamp_2026\05-monitoring\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Too many requests. For more on scraping GitHub and how it may affect your rights, please review our Terms of Service (https://docs.github.com/en/site-policy/github-terms/github-terms-of-service).

# %%
answer = rag.rag(
    "How does the agentic loop keep calling the model until it stops?"
)

# %%
answer = rag.rag(
    "How does the agentic loop keep calling the model until it stops?"
)

# %%
answer = rag.rag(
    "How does the agentic loop keep calling the model until it stops?"
)
